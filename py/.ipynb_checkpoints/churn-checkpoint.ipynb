# %%
import matplotlib.pyplot as plt
import json
import pandas as pd
import datetime as dt

# %%
f = open('data.json')
data = json.load(f) 

df = pd.json_normalize(data)

# %%
df['date'] = df['datetime'].apply(lambda x: dt.datetime.strptime(x,"%Y-%m-%dT%H:%M:%S%z").strftime("%Y-%m-%d"))
df['time'] = df['datetime'].apply(lambda x: dt.datetime.strptime(x,"%Y-%m-%dT%H:%M:%S%z").strftime("%H:%M"))
ans = [y for x, y in df.groupby('date', as_index=False)]


grouped = df.groupby(df.date)

for group_name, df_group in grouped:
    start = df_group["time"].min()
    openvalue =  df_group[(df_group['time'] == start)]
    df_group['day_open'] = openvalue['open'].values[0]
    df_group['norm_close'] = df_group['close'] / df_group['day_open']#row.close / row.day_open
    print(group_name,openvalue.open)
#     print(df_group)
# Out:
# 2022-01-20 0    1528.45
# Name: open, dtype: float64
# 2022-01-21 375    1500.0
# Name: open, dtype: float64
#        symbol                  datetime     high      low     open    close  \
# 375  HDFCBANK  2022-01-21T09:15:00+0530  1503.80  1488.05  1500.00  1492.85
# 376  HDFCBANK  2022-01-21T09:16:00+0530  1495.30  1492.95  1492.95  1494.65
# 377  HDFCBANK  2022-01-21T09:17:00+0530  1495.45  1493.00  1494.55  1494.85
# 378  HDFCBANK  2022-01-21T09:18:00+0530  1495.45  1493.10  1495.45  1494.25
# 379  HDFCBANK  2022-01-21T09:19:00+0530  1494.90  1493.00  1493.25  1494.30
# ..        ...                       ...      ...      ...      ...      ...
# 745  HDFCBANK  2022-01-21T15:25:00+0530  1526.80  1525.40  1525.45  1526.70
# 746  HDFCBANK  2022-01-21T15:26:00+0530  1527.30  1526.20  1526.70  1526.50
# 747  HDFCBANK  2022-01-21T15:27:00+0530  1527.40  1526.10  1526.10  1526.60
# 748  HDFCBANK  2022-01-21T15:28:00+0530  1528.90  1526.55  1526.75  1526.70
# 749  HDFCBANK  2022-01-21T15:29:00+0530  1529.00  1526.00  1526.70  1529.00
#
#      volume  oi   time        date  day_open  norm_close
# 375  224718   0  09:15  2022-01-21    1500.0    0.995233
# 376   53336   0  09:16  2022-01-21    1500.0    0.996433
# 377   41717   0  09:17  2022-01-21    1500.0    0.996567
# 378   28532   0  09:18  2022-01-21    1500.0    0.996167
# 379   34796   0  09:19  2022-01-21    1500.0    0.996200
# ..      ...  ..    ...         ...       ...         ...
# 745   43275   0  15:25  2022-01-21    1500.0    1.017800
# 746   63363   0  15:26  2022-01-21    1500.0    1.017667
# 747   29861   0  15:27  2022-01-21    1500.0    1.017733
# 748   43755   0  15:28  2022-01-21    1500.0    1.017800
# 749   15385   0  15:29  2022-01-21    1500.0    1.019333
#
# [375 rows x 12 columns]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_38652/3034499280.py in <module>
#      13     print(group_name,openvalue.open)
#      14 #     print(df_group)
# ---> 15 print(df_group).info()
#
# AttributeError: 'NoneType' object has no attribute 'info'

# %%
for group_name, df_group in grouped:
    print(group_name)
    y = df_group['close'] 
    x = df_group['time']
    plt.plot(x, y)
  
 
plt.show()
# Out:
# 2022-01-20
# 2022-01-21
